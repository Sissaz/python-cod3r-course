# %%
# Modulos

# python modulo_importar.py
# clear

# %%
# 1° Criar uma pasta para importar os modulos e uma subpasta para os modulos que serão importados
# 2° Criar um novo arquivo na subpasta chamado __int__.py

# %%
def modulofoto():
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    img = mpimg.imread('modulos.png')
    imgplot = plt.imshow(img)
    plt.show()
modulofoto()

# %%
# modulo.py

print(f"Foi importado o módulo {__name__} do pacote {__package__}.")

def soma(x,y):
    return x + y
# Out:
# Foi importado o módulo __main__ do pacote None.

# %%
# Na pasta para importar os modulos: 

from pacotes1 import modulo

print(type(modulo))
print(modulo.soma(2, 3))
# Out:
# <class 'module'>
# 5
